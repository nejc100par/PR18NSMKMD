# %%
import numpy as np
import pandas as pd
import Orange
# Out:
# C:\Users\Nejc\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
df1 = pd.read_csv('data/novi_pod/pn_5let_att.csv', sep=";")

# %%
df2 = pd.read_csv('data/novi_pod/pnose_5let_att.csv', sep=";")

# %%
asd = pd.merge(df1, df2, on='FIOStevilkaZadeve', how='outer')

# %%
asd
# Out:
#         FIOStevilkaZadeve cD#KlasifikacijaNesrece UpravnaEnotaStoritve  UraPN  \
# 0                  756803           BREZ POŠKODBE            LJUBLJANA      2
# 1                  756803           BREZ POŠKODBE            LJUBLJANA      2
# 2                  756895           BREZ POŠKODBE               KAMNIK     20
# 3                  758122           BREZ POŠKODBE            LJUBLJANA      1
# 4                  757080           BREZ POŠKODBE                PIRAN      4
# 5                  757397           BREZ POŠKODBE                IZOLA     12
# 6                  757305           BREZ POŠKODBE           NOVO MESTO     16
# 7                  757305           BREZ POŠKODBE           NOVO MESTO     16
# 8                  756936           BREZ POŠKODBE              BREŽICE      0
# 9                  756936           BREZ POŠKODBE              BREŽICE      0
# 10                 756936           BREZ POŠKODBE              BREŽICE      0
# ...

# %%
asd.to_csv('pn13-17_full.csv', sep=';', encoding='utf-8')
